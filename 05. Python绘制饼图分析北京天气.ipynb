# %% [markdown]
# ## Python绘制饼图分析北京天气
#
# 饼图，是一个划分为几个扇形的圆形统计图表，能够直接以图形的方式直接显示各个组成部分所占比例
#
# 目的：查看2019年北京天气数据，使用饼图查看天气、风向、空气质量的数据对比

# %% [markdown]
# ### 1. 编写函数-可以创建一个pyecharts饼图对象

# %%
from pyecharts import options as opts
from pyecharts.charts import Pie

# %%
def create_pie(datas, title) -> Pie:
    """ 创建饼图对象
    文档地址：https://pyecharts.org/#/zh-cn/basic_charts?id=pie%ef%bc%9a%e9%a5%bc%e5%9b%be
    @param datas: 数据，形式为[('晴', 115), ('多云', 78), ('晴~多云', 39)]
    @param title: 图表的标题
    """
    pie = Pie()
    pie.add("", datas)
    pie.set_global_opts(
        title_opts=opts.TitleOpts(title=title),
        legend_opts=opts.LegendOpts(pos_right="right")
    )
    pie.set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}: {d}%"))
    return pie

# %% [markdown]
# ### 2. 读取北京天气2019年数据

# %%
import pandas as pd

# %%
df = pd.read_csv("./datas/beijing_tianqi/beijing_tianqi_2019.csv")

# %%
df.head(5)
# Out:
#           ymd bWendu yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# 0  2019-01-01     1℃   -10℃   晴~多云       西北风     1级   56       良         2
# 1  2019-01-02     1℃    -9℃     多云       东北风     1级   60       良         2
# 2  2019-01-03     2℃    -7℃      霾       东北风     1级  165    中度污染         4
# 3  2019-01-04     2℃    -7℃      晴       西北风     2级   50       优         1
# 4  2019-01-05     0℃    -8℃     多云       东北风     2级   29       优         1

# %% [markdown]
# ### 3. 绘制饼图查看天气类型对比

# %%
df_tianqi = df.groupby("tianqi").size().sort_values(ascending=False)
df_tianqi
# Out:
# tianqi
# 晴         115
# 多云         78
# 晴~多云       39
# 多云~晴       34
# 小雨~多云      11
# 多云~雷阵雨     10
# 霾           8
# 多云~小雨       7
# 雷阵雨~多云      7
# 雷阵雨         7
# 阴~多云        5
# 多云~阴        4
# 小雨          4
# 雷阵雨~中雨      4
# 小雪~多云       4
# 阴~小雨        3
# 雷阵雨~晴       2
# 雷阵雨~小雨      2
# 霾~多云        2
# 中雨~多云       2
# 阴           2
# 中雨~小雨       2
# 多云~中雨       2
# 中雨~雷阵雨      2
# 阴~中雨        1
# 晴~霾         1
# 小雪          1
# 小雨~阴        1
# 小雨~晴        1
# 多云~中雪       1
# 雾~晴         1
# 霾~晴         1
# 霾~雾         1
# dtype: int64

# %%
datas = list(zip(df_tianqi.index.to_list(), df_tianqi.to_list()))
datas
# Out:
# [('晴', 115),
#  ('多云', 78),
#  ('晴~多云', 39),
#  ('多云~晴', 34),
#  ('小雨~多云', 11),
#  ('多云~雷阵雨', 10),
#  ('霾', 8),
#  ('多云~小雨', 7),
#  ('雷阵雨~多云', 7),
#  ('雷阵雨', 7),
#  ('阴~多云', 5),
#  ('多云~阴', 4),
#  ('小雨', 4),
#  ('雷阵雨~中雨', 4),
#  ('小雪~多云', 4),
#  ('阴~小雨', 3),
#  ('雷阵雨~晴', 2),
#  ('雷阵雨~小雨', 2),
#  ('霾~多云', 2),
#  ('中雨~多云', 2),
#  ('阴', 2),
#  ('中雨~小雨', 2),
#  ('多云~中雨', 2),
#  ('中雨~雷阵雨', 2),
#  ('阴~中雨', 1),
#  ('晴~霾', 1),
#  ('小雪', 1),
#  ('小雨~阴', 1),
#  ('小雨~晴', 1),
#  ('多云~中雪', 1),
#  ('雾~晴', 1),
#  ('霾~晴', 1),
#  ('霾~雾', 1)]

# %%
pie = create_pie(datas, "饼图-天气对比")
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="90128c172bfc497e9856a5b476188ad1" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_90128c172bfc497e9856a5b476188ad1 = echarts.init(
#                     document.getElementById('90128c172bfc497e9856a5b476188ad1'), 'white', {renderer: 'canvas'});
#                 var option_90128c172bfc497e9856a5b476188ad1 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 2,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "\u6674",
#                     "value": 115
#                 },
#                 {
#                     "name": "\u591a\u4e91",
#                     "value": 78
#                 },
#                 {
#                     "name": "\u6674~\u591a\u4e91",
#                     "value": 39
#                 },
#                 {
#                     "name": "\u591a\u4e91~\u6674",
#                     "value": 34
#                 },
#                 {
#                     "name": "\u5c0f\u96e8~\u591a\u4e91",
#                     "value": 11
#                 },
#                 {
#                     "name": "\u591a\u4e91~\u96f7\u9635\u96e8",
#                     "value": 10
#                 },
#                 {
#                     "name": "\u973e",
#                     "value": 8
#                 },
#                 {
#                     "name": "\u591a\u4e91~\u5c0f\u96e8",
#                     "value": 7
#                 },
#                 {
#                     "name": "\u96f7\u9635\u96e8~\u591a\u4e91",
#                     "value": 7
#                 },
#                 {
#                     "name": "\u96f7\u9635\u96e8",
#                     "value": 7
#                 },
#                 {
#                     "name": "\u9634~\u591a\u4e91",
#                     "value": 5
#                 },
#                 {
#                     "name": "\u591a\u4e91~\u9634",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u5c0f\u96e8",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u96f7\u9635\u96e8~\u4e2d\u96e8",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u5c0f\u96ea~\u591a\u4e91",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u9634~\u5c0f\u96e8",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u96f7\u9635\u96e8~\u6674",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u96f7\u9635\u96e8~\u5c0f\u96e8",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u973e~\u591a\u4e91",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u4e2d\u96e8~\u591a\u4e91",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u9634",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u4e2d\u96e8~\u5c0f\u96e8",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u591a\u4e91~\u4e2d\u96e8",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u4e2d\u96e8~\u96f7\u9635\u96e8",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u9634~\u4e2d\u96e8",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u6674~\u973e",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5c0f\u96ea",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5c0f\u96e8~\u9634",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5c0f\u96e8~\u6674",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u591a\u4e91~\u4e2d\u96ea",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u96fe~\u6674",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u973e~\u6674",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u973e~\u96fe",
#                     "value": 1
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "formatter": "{b}: {c}: {d}%",
#                 "valueAnimation": false
#             },
#             "labelLine": {
#                 "show": true,
#                 "showAbove": false,
#                 "length": 15,
#                 "length2": 15,
#                 "smooth": false,
#                 "minTurnAngle": 90,
#                 "maxSurfaceAngle": 90
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6674",
#                 "\u591a\u4e91",
#                 "\u6674~\u591a\u4e91",
#                 "\u591a\u4e91~\u6674",
#                 "\u5c0f\u96e8~\u591a\u4e91",
#                 "\u591a\u4e91~\u96f7\u9635\u96e8",
#                 "\u973e",
#                 "\u591a\u4e91~\u5c0f\u96e8",
#                 "\u96f7\u9635\u96e8~\u591a\u4e91",
#                 "\u96f7\u9635\u96e8",
#                 "\u9634~\u591a\u4e91",
#                 "\u591a\u4e91~\u9634",
#                 "\u5c0f\u96e8",
#                 "\u96f7\u9635\u96e8~\u4e2d\u96e8",
#                 "\u5c0f\u96ea~\u591a\u4e91",
#                 "\u9634~\u5c0f\u96e8",
#                 "\u96f7\u9635\u96e8~\u6674",
#                 "\u96f7\u9635\u96e8~\u5c0f\u96e8",
#                 "\u973e~\u591a\u4e91",
#                 "\u4e2d\u96e8~\u591a\u4e91",
#                 "\u9634",
#                 "\u4e2d\u96e8~\u5c0f\u96e8",
#                 "\u591a\u4e91~\u4e2d\u96e8",
#                 "\u4e2d\u96e8~\u96f7\u9635\u96e8",
#                 "\u9634~\u4e2d\u96e8",
#                 "\u6674~\u973e",
#                 "\u5c0f\u96ea",
#                 "\u5c0f\u96e8~\u9634",
#                 "\u5c0f\u96e8~\u6674",
#                 "\u591a\u4e91~\u4e2d\u96ea",
#                 "\u96fe~\u6674",

# %% [markdown]
# ### 4. 绘制饼图查看风向数据比例对比

# %%
df.head()
# Out:
#           ymd bWendu yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# 0  2019-01-01     1℃   -10℃   晴~多云       西北风     1级   56       良         2
# 1  2019-01-02     1℃    -9℃     多云       东北风     1级   60       良         2
# 2  2019-01-03     2℃    -7℃      霾       东北风     1级  165    中度污染         4
# 3  2019-01-04     2℃    -7℃      晴       西北风     2级   50       优         1
# 4  2019-01-05     0℃    -8℃     多云       东北风     2级   29       优         1

# %%
df_fengxiang = df.groupby("fengxiang").size().sort_values(ascending=False)
datas = list(zip(df_fengxiang.index.to_list(), df_fengxiang.to_list()))
pie = create_pie(datas, "饼图-风向")
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="1e27c4bb3eb5438cb94fad7860f70ff1" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_1e27c4bb3eb5438cb94fad7860f70ff1 = echarts.init(
#                     document.getElementById('1e27c4bb3eb5438cb94fad7860f70ff1'), 'white', {renderer: 'canvas'});
#                 var option_1e27c4bb3eb5438cb94fad7860f70ff1 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 2,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "\u4e1c\u5357\u98ce",
#                     "value": 104
#                 },
#                 {
#                     "name": "\u897f\u5317\u98ce",
#                     "value": 100
#                 },
#                 {
#                     "name": "\u897f\u5357\u98ce",
#                     "value": 81
#                 },
#                 {
#                     "name": "\u4e1c\u5317\u98ce",
#                     "value": 78
#                 },
#                 {
#                     "name": "\u5317\u98ce",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5357\u98ce",
#                     "value": 1
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "formatter": "{b}: {c}: {d}%",
#                 "valueAnimation": false
#             },
#             "labelLine": {
#                 "show": true,
#                 "showAbove": false,
#                 "length": 15,
#                 "length2": 15,
#                 "smooth": false,
#                 "minTurnAngle": 90,
#                 "maxSurfaceAngle": 90
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4e1c\u5357\u98ce",
#                 "\u897f\u5317\u98ce",
#                 "\u897f\u5357\u98ce",
#                 "\u4e1c\u5317\u98ce",
#                 "\u5317\u98ce",
#                 "\u5357\u98ce"
#             ],
#             "selected": {},
#             "show": true,
#             "right": "right",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "text": "\u997c\u56fe-\u98ce\u5411",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_1e27c4bb3eb5438cb94fad7860f70ff1.setOption(option_1e27c4bb3eb5438cb94fad7860f70ff1);
#         });
#     </script>

# %% [markdown]
# ### 5. 绘制饼图查看空气质量对比

# %%
df.head()
# Out:
#           ymd bWendu yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# 0  2019-01-01     1℃   -10℃   晴~多云       西北风     1级   56       良         2
# 1  2019-01-02     1℃    -9℃     多云       东北风     1级   60       良         2
# 2  2019-01-03     2℃    -7℃      霾       东北风     1级  165    中度污染         4
# 3  2019-01-04     2℃    -7℃      晴       西北风     2级   50       优         1
# 4  2019-01-05     0℃    -8℃     多云       东北风     2级   29       优         1

# %%
df_aqiInfo = df.groupby("aqiInfo").size().sort_values(ascending=False)
datas = list(zip(df_aqiInfo.index.to_list(), df_aqiInfo.to_list()))
pie = create_pie(datas, "饼图-空气质量")
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="fd454c3eb76042e2a0e08233e2e3e4e5" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_fd454c3eb76042e2a0e08233e2e3e4e5 = echarts.init(
#                     document.getElementById('fd454c3eb76042e2a0e08233e2e3e4e5'), 'white', {renderer: 'canvas'});
#                 var option_fd454c3eb76042e2a0e08233e2e3e4e5 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 2,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "\u826f",
#                     "value": 186
#                 },
#                 {
#                     "name": "\u4f18",
#                     "value": 114
#                 },
#                 {
#                     "name": "\u8f7b\u5ea6\u6c61\u67d3",
#                     "value": 47
#                 },
#                 {
#                     "name": "\u4e2d\u5ea6\u6c61\u67d3",
#                     "value": 13
#                 },
#                 {
#                     "name": "\u91cd\u5ea6\u6c61\u67d3",
#                     "value": 5
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "formatter": "{b}: {c}: {d}%",
#                 "valueAnimation": false
#             },
#             "labelLine": {
#                 "show": true,
#                 "showAbove": false,
#                 "length": 15,
#                 "length2": 15,
#                 "smooth": false,
#                 "minTurnAngle": 90,
#                 "maxSurfaceAngle": 90
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u826f",
#                 "\u4f18",
#                 "\u8f7b\u5ea6\u6c61\u67d3",
#                 "\u4e2d\u5ea6\u6c61\u67d3",
#                 "\u91cd\u5ea6\u6c61\u67d3"
#             ],
#             "selected": {},
#             "show": true,
#             "right": "right",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "text": "\u997c\u56fe-\u7a7a\u6c14\u8d28\u91cf",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_fd454c3eb76042e2a0e08233e2e3e4e5.setOption(option_fd454c3eb76042e2a0e08233e2e3e4e5);
#         });
#     </script>
