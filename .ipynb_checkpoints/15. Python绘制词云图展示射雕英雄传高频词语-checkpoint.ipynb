# %% [markdown]
# ## Python绘制词云图展示射雕英雄传高频词语
#
# 使用中文分词库Python库：jieba，自然语言处理必备，https://github.com/fxsjy/jieba

# %%
# !pip install jieba
import jieba
import jieba.analyse
import pandas as pd
import pyecharts.options as opts
from pyecharts.charts import WordCloud

# %% [markdown]
# ## 1、将小说文字分词

# %%
fin = open('射雕英雄传.txt', encoding='utf-8')
# 读取txt全部文字
txt = fin.read()

# %%
txt[:100]
# Out:
# '金庸全集之《射雕英雄传》\n作者:金庸\nwww.qisuu.com整理制作，并提供下载\n\n第一回\u3000风雪惊变\n钱塘江浩浩江水，日日夜夜无穷无休的从临安牛家村边\n绕过，东流入海。江畔一排数十株乌柏树，叶子似'

# %%
# 使用TF/IDF提取关键词
word_weights = jieba.analyse.extract_tags(
    txt, topK=50, withWeight=True)
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache C:\Users\212469~1\AppData\Local\Temp\jieba.cache
# Loading model cost 0.861 seconds.
# Prefix dict has been built successfully.

# %%
word_weights[:30]
# Out:
# [('郭靖', 0.12406614987375768),
#  ('黄蓉', 0.08107809133266804),
#  ('洪七公', 0.04578588205013813),
#  ('欧阳锋', 0.04504888596079989),
#  ('黄药师', 0.04142381491405629),
#  ('甚么', 0.03466305753512821),
#  ('周伯通', 0.03336783931722504),
#  ('武功', 0.025145981206282777),
#  ('黄蓉道', 0.02427480869257826),
#  ('丘处机', 0.02422551966124222),
#  ('郭靖道', 0.023537812603240022),
#  ('师父', 0.022435410894692275),
#  ('梅超风', 0.021280762079641663),
#  ('欧阳克', 0.021050450801723464),
#  ('说道', 0.019791592502254995),
#  ('柯镇恶', 0.018378839977872347),
#  ('裘千仞', 0.01768790614411775),
#  ('爹爹', 0.016514737153921474),
#  ('功夫', 0.0158321186453545),
#  ('两人', 0.015501687226510798),
#  ('心中', 0.014934863688623115),
#  ('完颜洪烈', 0.014509610508846589),
#  ('只见', 0.01427857030972316),
#  ('杨康', 0.01404898795301019),
#  ('穆念慈', 0.01386473893067563),
#  ('铁木真', 0.01381099345239756),
#  ('咱们', 0.013725115096530412),
#  ('心想', 0.013719964709228427),
#  ('一声', 0.013480558228988344),
#  ('完颜康', 0.01340411637483923)]

# %% [markdown]
# ### 2、绘制词云图

# %%
word_cloud = (
    WordCloud()
    .add(series_name="高频词语", 
         data_pair=word_weights, word_size_range=[10, 50])
    .set_global_opts(
        title_opts=opts.TitleOpts(
            title="射雕英雄传-高频词云图", 
            title_textstyle_opts=opts.TextStyleOpts(font_size=23),
            pos_left='center')
    )
)

# %%
word_cloud.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/v5/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="0483858fc2ce4a3b967af868693d9ea7" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_0483858fc2ce4a3b967af868693d9ea7 = echarts.init(
#                     document.getElementById('0483858fc2ce4a3b967af868693d9ea7'), 'white', {renderer: 'canvas'});
#                 var option_0483858fc2ce4a3b967af868693d9ea7 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "name": "\u9ad8\u9891\u8bcd\u8bed",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 10,
#                 50
#             ],
#             "data": [
#                 {
#                     "name": "\u90ed\u9756",
#                     "value": 0.12406614987375768,
#                     "textStyle": {
#                         "color": "rgb(141,18,88)"
#                     }
#                 },
#                 {
#                     "name": "\u9ec4\u84c9",
#                     "value": 0.08107809133266804,
#                     "textStyle": {
#                         "color": "rgb(84,21,121)"
#                     }
#                 },
#                 {
#                     "name": "\u6d2a\u4e03\u516c",
#                     "value": 0.04578588205013813,
#                     "textStyle": {
#                         "color": "rgb(69,12,122)"
#                     }
#                 },
#                 {
#                     "name": "\u6b27\u9633\u950b",
#                     "value": 0.04504888596079989,
#                     "textStyle": {
#                         "color": "rgb(30,148,70)"
#                     }
#                 },
#                 {
#                     "name": "\u9ec4\u836f\u5e08",
#                     "value": 0.04142381491405629,
#                     "textStyle": {
#                         "color": "rgb(146,42,109)"
#                     }
#                 },
#                 {
#                     "name": "\u751a\u4e48",
#                     "value": 0.03466305753512821,
#                     "textStyle": {
#                         "color": "rgb(106,12,113)"
#                     }
#                 },
#                 {
#                     "name": "\u5468\u4f2f\u901a",
#                     "value": 0.03336783931722504,
#                     "textStyle": {
#                         "color": "rgb(16,66,132)"
#                     }
#                 },
#                 {
#                     "name": "\u6b66\u529f",
#                     "value": 0.025145981206282777,
#                     "textStyle": {
#                         "color": "rgb(20,34,12)"
#                     }
#                 },
#                 {
#                     "name": "\u9ec4\u84c9\u9053",
#                     "value": 0.02427480869257826,
#                     "textStyle": {
#                         "color": "rgb(95,102,105)"
#                     }
#                 },
#                 {
#                     "name": "\u4e18\u5904\u673a",
#                     "value": 0.02422551966124222,
#                     "textStyle": {
#                         "color": "rgb(84,63,125)"
#                     }
#                 },
#                 {
#                     "name": "\u90ed\u9756\u9053",
#                     "value": 0.023537812603240022,
#                     "textStyle": {
#                         "color": "rgb(94,68,93)"
#                     }
#                 },
#                 {
#                     "name": "\u5e08\u7236",
#                     "value": 0.022435410894692275,
#                     "textStyle": {
#                         "color": "rgb(114,6,7)"
#                     }
#                 },
#                 {
#                     "name": "\u6885\u8d85\u98ce",
#                     "value": 0.021280762079641663,
#                     "textStyle": {
#                         "color": "rgb(55,151,116)"
#                     }
#                 },
#                 {
#                     "name": "\u6b27\u9633\u514b",
#                     "value": 0.021050450801723464,
#                     "textStyle": {
#                         "color": "rgb(120,139,12)"
#                     }
#                 },
#                 {
#                     "name": "\u8bf4\u9053",
#                     "value": 0.019791592502254995,
#                     "textStyle": {
#                         "color": "rgb(158,43,31)"
#                     }
#                 },
#                 {
#                     "name": "\u67ef\u9547\u6076",
#                     "value": 0.018378839977872347,
#                     "textStyle": {
#                         "color": "rgb(93,11,4)"
#                     }
#                 },
#                 {
#                     "name": "\u88d8\u5343\u4ede",
#                     "value": 0.01768790614411775,
#                     "textStyle": {
#                         "color": "rgb(30,137,116)"
#                     }
#                 },
#                 {
#                     "name": "\u7239\u7239",
#                     "value": 0.016514737153921474,
#                     "textStyle": {
#                         "color": "rgb(112,154,29)"
#                     }
#                 },
#                 {
#                     "name": "\u529f\u592b",
#                     "value": 0.0158321186453545,
#                     "textStyle": {
#                         "color": "rgb(149,99,91)"
#                     }
#                 },
#                 {
#                     "name": "\u4e24\u4eba",
#                     "value": 0.015501687226510798,
#                     "textStyle": {
#                         "color": "rgb(66,30,65)"
#                     }
#                 },
#                 {
#                     "name": "\u5fc3\u4e2d",
#                     "value": 0.014934863688623115,
#                     "textStyle": {
#                         "color": "rgb(49,94,22)"
#                     }
#                 },
#                 {
#                     "name": "\u5b8c\u989c\u6d2a\u70c8",
#                     "value": 0.014509610508846589,
#                     "textStyle": {
#                         "color": "rgb(52,103,118)"
#                     }
#                 },
#                 {
#                     "name": "\u53ea\u89c1",
#                     "value": 0.01427857030972316,
#                     "textStyle": {
#                         "color": "rgb(68,3,109)"
#                     }
#                 },
#                 {
#                     "name": "\u6768\u5eb7",
#                     "value": 0.01404898795301019,
#                     "textStyle": {
#                         "color": "rgb(11,110,77)"
#                     }
#                 },
#                 {
#                     "name": "\u7a46\u5ff5\u6148",
#                     "value": 0.01386473893067563,
#                     "textStyle": {
#                         "color": "rgb(123,80,156)"
#                     }
#                 },
#                 {
#                     "name": "\u94c1\u6728\u771f",
#                     "value": 0.01381099345239756,
#                     "textStyle": {
#                         "color": "rgb(16,15,155)"
#                     }
#                 },
#                 {
#                     "name": "\u54b1\u4eec",
#                     "value": 0.013725115096530412,
#                     "textStyle": {
